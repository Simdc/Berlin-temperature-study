# %%
import pandas as pd
import numpy as np

# %%
LCZ_2_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_night_00_40.DAT",",")
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\3187031174.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_2_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_night_00_40.DAT",",")

# %%
LCZ_2_night_00_40["Datetime"] = pd.to_datetime(LCZ_2_night_00_40["Datetime"])

# %%
LCZ_2_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_night_00_40.DAT",",")
LCZ_4_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_night_00_40.DAT",",")
LCZ_6_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_night_00_40.DAT",",")
LCZ_A_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_A_night_00_40.DAT",",")
LCZ_B_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_B_night_00_40.DAT",",")
LCZ_D_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_D_night_00_40.DAT",",")
LCZ_G_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_G_night_00_40.DAT",",")
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\2151176341.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_2_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_night_00_40.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\2151176341.py:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_4_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_night_00_40.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\2151176341.py:3: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_6_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_night_00_40.DAT",",")
# ...

# %%
LCZ_2_night_00_40["Datetime"]=pd.to_datetime(LCZ_2_night_00_40["Datetime"])
LCZ_4_night_00_40["Datetime"]=pd.to_datetime(LCZ_4_night_00_40["Datetime"])
LCZ_6_night_00_40["Datetime"]=pd.to_datetime(LCZ_6_night_00_40["Datetime"])
LCZ_A_night_00_40["Datetime"]=pd.to_datetime(LCZ_A_night_00_40["Datetime"])
LCZ_B_night_00_40["Datetime"]=pd.to_datetime(LCZ_B_night_00_40["Datetime"])
LCZ_D_night_00_40["Datetime"]=pd.to_datetime(LCZ_D_night_00_40["Datetime"])
LCZ_G_night_00_40["Datetime"]=pd.to_datetime(LCZ_G_night_00_40["Datetime"])

# %%
LCZ_2_night_00_40.resample(rule='D', on = 'Datetime').mean().plot(ylim=(0,30)).get_figure().savefig('LCZ_2_night_temperature_Daily.png')
LCZ_4_night_00_40.resample(rule='D', on = 'Datetime').mean().plot(ylim=(0,30)).get_figure().savefig('LCZ_4_night_temperature_Daily.png')
LCZ_6_night_00_40.resample(rule='D', on = 'Datetime').mean().plot(ylim=(0,30)).get_figure().savefig('LCZ_6_night_temperature_Daily.png')
LCZ_A_night_00_40.resample(rule='D', on = 'Datetime').mean().plot(ylim=(0,30)).get_figure().savefig('LCZ_A_night_temperature_Daily.png')
LCZ_B_night_00_40.resample(rule='D', on = 'Datetime').mean().plot(ylim=(0,30)).get_figure().savefig('LCZ_B_night_temperature_Daily.png')
LCZ_D_night_00_40.resample(rule='D', on = 'Datetime').mean().plot(ylim=(0,30)).get_figure().savefig('LCZ_D_night_temperature_Daily.png')
LCZ_G_night_00_40.resample(rule='D', on = 'Datetime').mean().plot(ylim=(0,30)).get_figure().savefig('LCZ_G_night_temperature_Daily.png')

# %%
LCZ_2_night_00_40.groupby(LCZ_2_night_00_40["Datetime"].dt.hour)["18_Schillerstr_UTC_05min_ta_2022-07","19_Galvanistr_UTC_05min_ta_2022-07","33_Jagow_UTC_05min_ta_2022-07","34_Planetarium_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_2_night_temperature_bar.png')
LCZ_2_night_00_40.groupby(LCZ_2_night_00_40["Datetime"].dt.month_name())["18_Schillerstr_UTC_05min_ta_2022-07","19_Galvanistr_UTC_05min_ta_2022-07","33_Jagow_UTC_05min_ta_2022-07","34_Planetarium_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Monthly_LCZ_2_night_temperature_bar.png')
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\3010691118.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_2_night_00_40.groupby(LCZ_2_night_00_40["Datetime"].dt.hour)["18_Schillerstr_UTC_05min_ta_2022-07","19_Galvanistr_UTC_05min_ta_2022-07","33_Jagow_UTC_05min_ta_2022-07","34_Planetarium_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_2_night_temperature_bar.png')
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\3010691118.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
LCZ_4_night_00_40.groupby(LCZ_4_night_00_40["Datetime"].dt.hour)["28_Marzahn_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_4_night_temperature_bar.png')
LCZ_4_night_00_40.groupby(LCZ_4_night_00_40["Datetime"].dt.month_name())["28_Marzahn_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Monthly_LCZ_4_night_temperature_bar.png')

# %%
LCZ_6_night_00_40.groupby(LCZ_6_night_00_40["Datetime"].dt.hour)["01_Amselgrund-1_UTC_05min_ta_2022-07","02_Amselgrund-2_UTC_05min_ta_2022-07","08_Prignitzstr_UTC_05min_ta_2022-07","12_Petitweg_UTC_05min_ta_2022-07","17_Martin-Hoffmannstr_UTC_05min_ta_2022-07","31_Fichtenberg_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_6_night_temperature_bar.png')
LCZ_6_night_00_40.groupby(LCZ_6_night_00_40["Datetime"].dt.month_name())["01_Amselgrund-1_UTC_05min_ta_2022-07","02_Amselgrund-2_UTC_05min_ta_2022-07","08_Prignitzstr_UTC_05min_ta_2022-07","12_Petitweg_UTC_05min_ta_2022-07","17_Martin-Hoffmannstr_UTC_05min_ta_2022-07","31_Fichtenberg_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Monthly_LCZ_6_night_temperature_bar.png')
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\30310890.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_6_night_00_40.groupby(LCZ_6_night_00_40["Datetime"].dt.hour)["01_Amselgrund-1_UTC_05min_ta_2022-07","02_Amselgrund-2_UTC_05min_ta_2022-07","08_Prignitzstr_UTC_05min_ta_2022-07","12_Petitweg_UTC_05min_ta_2022-07","17_Martin-Hoffmannstr_UTC_05min_ta_2022-07","31_Fichtenberg_UTC_05min_ta_2022-07"].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_6_night_temperature_bar.png')
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\30310890.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
LCZ_A_night_00_40.groupby(LCZ_A_night_00_40["Datetime"].dt.hour)['04_Preiss-1_UTC_05min_ta_2022-07','05_Preiss-2_UTC_05min_ta_2022-07','07_Wald-Tegel_UTC_05min_ta_2022-07','26_Tegel-Forst_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_A_night_temperature_bar.png')
LCZ_A_night_00_40.groupby(LCZ_A_night_00_40["Datetime"].dt.month_name())['04_Preiss-1_UTC_05min_ta_2022-07','05_Preiss-2_UTC_05min_ta_2022-07','07_Wald-Tegel_UTC_05min_ta_2022-07','26_Tegel-Forst_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Monthly_LCZ_A_night_temperature_bar.png')
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\1241588525.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_A_night_00_40.groupby(LCZ_A_night_00_40["Datetime"].dt.hour)['04_Preiss-1_UTC_05min_ta_2022-07','05_Preiss-2_UTC_05min_ta_2022-07','07_Wald-Tegel_UTC_05min_ta_2022-07','26_Tegel-Forst_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_A_night_temperature_bar.png')
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\1241588525.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
LCZ_B_night_00_40.groupby(LCZ_B_night_00_40["Datetime"].dt.hour)['20_Zoo_UTC_05min_ta_2022-07','21_Waldschulallee_UTC_05min_ta_2022-07','22_Botanischer-Garten_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_B_night_temperature_bar.png')
LCZ_B_night_00_40.groupby(LCZ_B_night_00_40["Datetime"].dt.month_name())['20_Zoo_UTC_05min_ta_2022-07','21_Waldschulallee_UTC_05min_ta_2022-07','22_Botanischer-Garten_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Monthly_LCZ_B_night_temperature_bar.png')
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\3079930428.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_B_night_00_40.groupby(LCZ_B_night_00_40["Datetime"].dt.hour)['20_Zoo_UTC_05min_ta_2022-07','21_Waldschulallee_UTC_05min_ta_2022-07','22_Botanischer-Garten_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_B_night_temperature_bar.png')
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\3079930428.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
LCZ_D_night_00_40.groupby(LCZ_D_night_00_40["Datetime"].dt.hour)['10_Buchholzerstr_UTC_05min_ta_2022-07','11_Elisabeth-Aue_UTC_05min_ta_2022-07','29_Gatow_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_D_night_temperature_bar.png')
LCZ_D_night_00_40.groupby(LCZ_D_night_00_40["Datetime"].dt.month_name())['10_Buchholzerstr_UTC_05min_ta_2022-07','11_Elisabeth-Aue_UTC_05min_ta_2022-07','29_Gatow_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Monthly_LCZ_D_night_temperature_bar.png')
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\1820503991.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_D_night_00_40.groupby(LCZ_D_night_00_40["Datetime"].dt.hour)['10_Buchholzerstr_UTC_05min_ta_2022-07','11_Elisabeth-Aue_UTC_05min_ta_2022-07','29_Gatow_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_D_night_temperature_bar.png')
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\1820503991.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
LCZ_G_night_00_40.groupby(LCZ_G_night_00_40["Datetime"].dt.hour)['06_Ruderclub_UTC_05min_ta_2022-07','23_Mueggelsee_UTC_05min_ta_2022-07','25_Tegeler-See_UTC_05min_ta_2022-07','27_Pichelsdorf_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_G_night_temperature_bar.png')
LCZ_G_night_00_40.groupby(LCZ_G_night_00_40["Datetime"].dt.month_name())['06_Ruderclub_UTC_05min_ta_2022-07','23_Mueggelsee_UTC_05min_ta_2022-07','25_Tegeler-See_UTC_05min_ta_2022-07','27_Pichelsdorf_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Month_LCZ_G_night_temperature_bar.png')
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\1818395006.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_G_night_00_40.groupby(LCZ_G_night_00_40["Datetime"].dt.hour)['06_Ruderclub_UTC_05min_ta_2022-07','23_Mueggelsee_UTC_05min_ta_2022-07','25_Tegeler-See_UTC_05min_ta_2022-07','27_Pichelsdorf_UTC_05min_ta_2022-07'].mean().plot(ylim=(0,20),kind='bar').legend(loc='lower left').get_figure().savefig('Daily_LCZ_G_night_temperature_bar.png')
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\1818395006.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
LCZ_2_night_00_40.resample(rule='30T', on = 'Datetime').mean().plot(ylim=(0,30))#.get_figure().savefig('LCZ_2_night_temperature_Daily.png')
LCZ_4_night_00_40.resample(rule='30T', on = 'Datetime').mean().plot(ylim=(0,30))#.get_figure().savefig('LCZ_4_night_temperature_Daily.png')
LCZ_6_night_00_40.resample(rule='30T', on = 'Datetime').mean().plot(ylim=(0,30))#.get_figure().savefig('LCZ_6_night_temperature_Daily.png')
LCZ_A_night_00_40.resample(rule='30T', on = 'Datetime').mean().plot(ylim=(0,30))#.get_figure().savefig('LCZ_A_night_temperature_Daily.png')
LCZ_B_night_00_40.resample(rule='30T', on = 'Datetime').mean().plot(ylim=(0,30))#.get_figure().savefig('LCZ_B_night_temperature_Daily.png')
LCZ_D_night_00_40.resample(rule='30T', on = 'Datetime').mean().plot(ylim=(0,30))#.get_figure().savefig('LCZ_D_night_temperature_Daily.png')
LCZ_G_night_00_40.resample(rule='30T', on = 'Datetime').mean().plot(ylim=(0,30))#.get_figure().savefig('LCZ_G_night_temperature_Daily.png')
# Out:
# <Axes: xlabel='Datetime'>

# %%
LCZ_2_night_00_40=LCZ_2_night_00_40.rename(columns ={"average": "LCZ_2_average"})
LCZ_4_night_00_40=LCZ_4_night_00_40.rename(columns ={"average": "LCZ_4_average"})
LCZ_6_night_00_40=LCZ_6_night_00_40.rename(columns ={"average": "LCZ_6_average"})
LCZ_A_night_00_40=LCZ_A_night_00_40.rename(columns ={"average": "LCZ_A_average"})
LCZ_B_night_00_40=LCZ_B_night_00_40.rename(columns ={"average": "LCZ_B_average"})
LCZ_D_night_00_40=LCZ_D_night_00_40.rename(columns ={"average": "LCZ_D_average"})
LCZ_G_night_00_40=LCZ_G_night_00_40.rename(columns ={"average": "LCZ_G_average"})

# %%
LCZ_6_night_00_40
# Out:
#                 Datetime  01_Amselgrund-1_UTC_05min_ta_2022-07  \
# 0    2022-07-01 00:00:00                                 19.67
# 1    2022-07-01 00:05:00                                 19.60
# 2    2022-07-01 00:10:00                                 19.58
# 3    2022-07-01 00:15:00                                 19.49
# 4    2022-07-01 00:20:00                                 19.51
# ...                  ...                                   ...
# 4503 2022-09-30 03:40:00                                  2.90
# 4504 2022-09-30 03:45:00                                  2.88
# 4505 2022-09-30 03:50:00                                  2.84
# 4506 2022-09-30 03:55:00                                  2.85
# 4507 2022-09-30 04:00:00                                  2.86
#
#       02_Amselgrund-2_UTC_05min_ta_2022-07  \
# 0                                    19.25
# 1                                    19.20
# 2                                    19.12
# ...

# %%
all_averages = pd.DataFrame()
all_averages.insert(0,'Datetime',LCZ_2_night_00_40["Datetime"], True)
all_averages.insert(1,'LCZ_2_average',LCZ_2_night_00_40["LCZ_2_average"], True)
all_averages.insert(2,'LCZ_4_average',LCZ_4_night_00_40["LCZ_4_average"], True)
all_averages.insert(3,'LCZ_6_average',LCZ_6_night_00_40["LCZ_6_average"], True)
all_averages.insert(4,'LCZ_A_average',LCZ_A_night_00_40["LCZ_A_average"], True)
all_averages.insert(5,'LCZ_B_average',LCZ_B_night_00_40["LCZ_B_average"], True)
all_averages.insert(6,'LCZ_D_average',LCZ_D_night_00_40["LCZ_D_average"], True)
all_averages.insert(7,'LCZ_G_average',LCZ_G_night_00_40["LCZ_G_average"], True)

all_averages
# Out:
#                 Datetime  LCZ_2_average  LCZ_4_average  LCZ_6_average  \
# 0    2022-07-01 00:00:00        22.4075           19.2      19.828333
# 1    2022-07-01 00:05:00        22.4350           19.2      19.763333
# 2    2022-07-01 00:10:00        22.3825           19.2      19.733333
# 3    2022-07-01 00:15:00        22.3200           19.2      19.675000
# 4    2022-07-01 00:20:00        22.3075           19.2      19.620000
# ...                  ...            ...            ...            ...
# 4503 2022-09-30 03:40:00         6.4625            4.0       2.990000
# 4504 2022-09-30 03:45:00         6.3950            4.0       2.983333
# 4505 2022-09-30 03:50:00         6.3850            4.0       2.961667
# 4506 2022-09-30 03:55:00         6.3275            4.0       2.975000
# 4507 2022-09-30 04:00:00         6.2850            4.0       2.940000
#
#       LCZ_A_average  LCZ_B_average  LCZ_D_average  LCZ_G_average
# ...

# %%
all_averages.set_index("Datetime")
# Out:
#                      LCZ_2_average  LCZ_4_average  LCZ_6_average  \
# Datetime
# 2022-07-01 00:00:00        22.4075           19.2      19.828333
# 2022-07-01 00:05:00        22.4350           19.2      19.763333
# 2022-07-01 00:10:00        22.3825           19.2      19.733333
# 2022-07-01 00:15:00        22.3200           19.2      19.675000
# 2022-07-01 00:20:00        22.3075           19.2      19.620000
# ...                            ...            ...            ...
# 2022-09-30 03:40:00         6.4625            4.0       2.990000
# 2022-09-30 03:45:00         6.3950            4.0       2.983333
# 2022-09-30 03:50:00         6.3850            4.0       2.961667
# 2022-09-30 03:55:00         6.3275            4.0       2.975000
# 2022-09-30 04:00:00         6.2850            4.0       2.940000
#
#                      LCZ_A_average  LCZ_B_average  LCZ_D_average  \
# Datetime
# 2022-07-01 00:00:00        19.6000      21.193333      18.543333
# ...

# %%
all_averages.reset_index()
all_averages.resample(rule='D', on = 'Datetime').mean().plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
all_averages.corr()
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\2817180391.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   all_averages.corr()
#                LCZ_2_average  LCZ_4_average  LCZ_6_average  LCZ_A_average  \
# LCZ_2_average       1.000000       0.931929       0.966649       0.947649
# LCZ_4_average       0.931929       1.000000       0.982173       0.972161
# LCZ_6_average       0.966649       0.982173       1.000000       0.989546
# LCZ_A_average       0.947649       0.972161       0.989546       1.000000
# LCZ_B_average       0.963660       0.977187       0.993101       0.983382
# LCZ_D_average       0.873594       0.966671       0.956301       0.967775
# LCZ_G_average       0.983459       0.971325       0.989130       0.981782
#
#                LCZ_B_average  LCZ_D_average  LCZ_G_average
# ...

# %%
LCZ_6_night_00_40_corr = LCZ_6_night_00_40.loc[:, LCZ_6_night_00_40.columns!='LCZ_6_average']

# %%
LCZ_6_night_00_40_corr.set_index("Datetime")
# Out:
#                      01_Amselgrund-1_UTC_05min_ta_2022-07  \
# Datetime
# 2022-07-01 00:00:00                                 19.67
# 2022-07-01 00:05:00                                 19.60
# 2022-07-01 00:10:00                                 19.58
# 2022-07-01 00:15:00                                 19.49
# 2022-07-01 00:20:00                                 19.51
# ...                                                   ...
# 2022-09-30 03:40:00                                  2.90
# 2022-09-30 03:45:00                                  2.88
# 2022-09-30 03:50:00                                  2.84
# 2022-09-30 03:55:00                                  2.85
# 2022-09-30 04:00:00                                  2.86
#
#                      02_Amselgrund-2_UTC_05min_ta_2022-07  \
# Datetime
# 2022-07-01 00:00:00                                 19.25
# 2022-07-01 00:05:00                                 19.20
# 2022-07-01 00:10:00                                 19.12
# ...

# %%
LCZ_6_night_00_40_corr.corr()
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\3688454559.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   LCZ_6_night_00_40_corr.corr()
#                                             01_Amselgrund-1_UTC_05min_ta_2022-07  \
# 01_Amselgrund-1_UTC_05min_ta_2022-07                                    1.000000
# 02_Amselgrund-2_UTC_05min_ta_2022-07                                    0.998631
# 08_Prignitzstr_UTC_05min_ta_2022-07                                     0.977140
# 12_Petitweg_UTC_05min_ta_2022-07                                        0.990742
# 17_Martin-Hoffmannstr_UTC_05min_ta_2022-07                              0.956104
# 31_Fichtenberg_UTC_05min_ta_2022-07                                     0.951328
#
#                                             02_Amselgrund-2_UTC_05min_ta_2022-07  \
# ...

# %%
LCZ_2_night_00_40_corr = LCZ_2_night_00_40.loc[:, LCZ_2_night_00_40.columns!='LCZ_2_average']

# %%
LCZ_2_night_00_40_corr.set_index("Datetime")
# Out:
#                      18_Schillerstr_UTC_05min_ta_2022-07  \
# Datetime
# 2022-07-01 00:00:00                                22.87
# 2022-07-01 00:05:00                                22.82
# 2022-07-01 00:10:00                                22.73
# 2022-07-01 00:15:00                                22.68
# 2022-07-01 00:20:00                                22.60
# ...                                                  ...
# 2022-09-30 03:40:00                                 7.55
# 2022-09-30 03:45:00                                 7.40
# 2022-09-30 03:50:00                                 7.39
# 2022-09-30 03:55:00                                 7.20
# 2022-09-30 04:00:00                                 7.10
#
#                      19_Galvanistr_UTC_05min_ta_2022-07  \
# Datetime
# 2022-07-01 00:00:00                               22.66
# 2022-07-01 00:05:00                               22.72
# 2022-07-01 00:10:00                               22.70
# ...

# %%
LCZ_2_night_00_40_corr.corr()
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_9312\1514225594.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   LCZ_2_night_00_40_corr.corr()
#                                      18_Schillerstr_UTC_05min_ta_2022-07  \
# 18_Schillerstr_UTC_05min_ta_2022-07                             1.000000
# 19_Galvanistr_UTC_05min_ta_2022-07                              0.996624
# 33_Jagow_UTC_05min_ta_2022-07                                   0.998183
# 34_Planetarium_UTC_05min_ta_2022-07                             0.986053
#
#                                      19_Galvanistr_UTC_05min_ta_2022-07  \
# 18_Schillerstr_UTC_05min_ta_2022-07                            0.996624
# 19_Galvanistr_UTC_05min_ta_2022-07                             1.000000
# 33_Jagow_UTC_05min_ta_2022-07                                  0.997442
# ...

# %%
#############################################################################################################################

# %%
LCZ_2_A_night = pd.DataFrame()
LCZ_2_A_night.insert(0,"Datetime",all_averages["Datetime"])
LCZ_2_A_night.insert(1,"LCZ_4_average",all_averages["LCZ_4_average"])
LCZ_2_A_night.insert(2,"LCZ_G_average",all_averages["LCZ_G_average"])

# %%
LCZ_2_A_night.dropna(inplace=True)
LCZ_2_A_night
# Out:
#                 Datetime  LCZ_4_average  LCZ_G_average
# 0    2022-07-01 00:00:00           19.2        21.0350
# 1    2022-07-01 00:05:00           19.2        20.9625
# 2    2022-07-01 00:10:00           19.2        20.9725
# 3    2022-07-01 00:15:00           19.2        20.9775
# 4    2022-07-01 00:20:00           19.2        20.9425
# ...                  ...            ...            ...
# 4503 2022-09-30 03:40:00            4.0         5.6800
# 4504 2022-09-30 03:45:00            4.0         5.6875
# 4505 2022-09-30 03:50:00            4.0         5.7550
# 4506 2022-09-30 03:55:00            4.0         5.7675
# 4507 2022-09-30 04:00:00            4.0         5.6450
#
# [4508 rows x 3 columns]

# %%
LCZ_2_A_night.resample(rule='D', on = 'Datetime').mean().plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')
    result = pd.Series(dftest[0:4], index=['Test Statistic','P-value','Lags Used','No of Observations'])
    for key,value in dftest[4].items():
        result['Critical Value (%s)'%key] = value
    return result

# %%
adf_table = LCZ_2_A_night.drop('Datetime', axis = 1)
adf_table.apply(adf_test, axis = 0)
# Out:
#                       LCZ_4_average  LCZ_G_average
# Test Statistic            -3.436794      -3.441309
# P-value                    0.009767       0.009629
# Lags Used                  0.000000       0.000000
# No of Observations      4507.000000    4507.000000
# Critical Value (1%)       -3.431802      -3.431802
# Critical Value (5%)       -2.862182      -2.862182
# Critical Value (10%)      -2.567111      -2.567111

# %%
from scipy import signal
def ccf_values(series1, series2):
    p = series1
    q = series2
    p = (p - np.mean(p)) / (np.std(p)*len(p))
    q = (q - np.mean(q)) / (np.std(q))  
    c = np.correlate(p, q, 'full')
    return c

# %%
ccf_ielts = ccf_values(LCZ_2_A_night['LCZ_4_average'], LCZ_2_A_night['LCZ_G_average'])
ccf_ielts
# Out:
# array([-0.00065251, -0.00129657, -0.0019415 , ..., -0.00283799,
#        -0.00189481, -0.00095324])

# %%
lags = signal.correlation_lags(len(LCZ_2_A_night['LCZ_4_average']), len(LCZ_2_A_night['LCZ_G_average']))

# %%
def ccf_plot(lags, ccf):
    import matplotlib.pyplot as plt
    fig, ax =plt.subplots(figsize=(9, 6))
    ax.plot(lags, ccf)
    ax.axhline(-2/np.sqrt(23), color='red', label='5% confidence interval')
    ax.axhline(2/np.sqrt(23), color='red')
    ax.axvline(x = 0, color = 'black', lw = 1)
    ax.axhline(y = 0, color = 'black', lw = 1)
    ax.axhline(y = np.max(ccf), color = 'blue', lw = 1, linestyle='--', label = 'highest +/- correlation')
    ax.axhline(y = np.min(ccf), color = 'blue', lw = 1, linestyle='--')
    ax.set(ylim = [-1, 1])
    ax.set_title('Cross Correation LCZ_4_average and LCZ_G_average', weight='bold', fontsize = 15)
    ax.set_ylabel('Correlation Coefficients', weight='bold', fontsize = 12)
    ax.set_xlabel('Time Lags', weight='bold', fontsize = 12)
    plt.legend()

# %%
ccf_plot(lags, ccf_ielts)

# %%
#############################################################################################################################

# %%
LCZ_2_A_night_test = pd.DataFrame()
LCZ_2_A_night_test.insert(0,"Datetime",all_averages["Datetime"])
LCZ_2_A_night_test.insert(1,"LCZ_4_average",all_averages["LCZ_4_average"])
LCZ_2_A_night_test.insert(2,"LCZ_G_average",all_averages["LCZ_G_average"])

# %%
LCZ_2_A_night_test.resample("H",on="Datetime").mean()
# Out:
#                      LCZ_4_average  LCZ_G_average
# Datetime
# 2022-07-01 00:00:00      19.150000      20.893750
# 2022-07-01 01:00:00      18.908333      20.586042
# 2022-07-01 02:00:00      18.833333      20.372500
# 2022-07-01 03:00:00      19.333333      20.582708
# 2022-07-01 04:00:00      19.800000      20.975000
# ...                            ...            ...
# 2022-09-30 00:00:00       5.208333       6.619583
# 2022-09-30 01:00:00       4.700000       6.182917
# 2022-09-30 02:00:00       4.216667       5.670833
# 2022-09-30 03:00:00       4.058333       5.640833
# 2022-09-30 04:00:00       4.000000       5.645000
#
# [2189 rows x 2 columns]

# %%
adf_table1 = LCZ_2_A_night_test.drop('Datetime', axis = 1)
adf_table1.apply(adf_test, axis = 0)
# Out:
#                       LCZ_4_average  LCZ_G_average
# Test Statistic            -3.436794      -3.441309
# P-value                    0.009767       0.009629
# Lags Used                  0.000000       0.000000
# No of Observations      4507.000000    4507.000000
# Critical Value (1%)       -3.431802      -3.431802
# Critical Value (5%)       -2.862182      -2.862182
# Critical Value (10%)      -2.567111      -2.567111

# %%
ccf_ielts1 = ccf_values(LCZ_2_A_night_test['LCZ_4_average'], LCZ_2_A_night_test['LCZ_G_average'])
ccf_ielts1
# Out:
# array([-0.00065251, -0.00129657, -0.0019415 , ..., -0.00283799,
#        -0.00189481, -0.00095324])

# %%
lags1 = signal.correlation_lags(len(LCZ_2_A_night_test['LCZ_4_average']), len(LCZ_2_A_night_test['LCZ_G_average']))

# %%
ccf_plot(lags1, ccf_ielts1)

# %%
####################################################################################################################

# %%
LCZ_2_A_night_test2 = pd.DataFrame()
LCZ_2_A_night_test2.insert(0,"Datetime",all_averages["Datetime"])
LCZ_2_A_night_test2.insert(1,"LCZ_4_average",all_averages["LCZ_4_average"])
LCZ_2_A_night_test2.insert(2,"LCZ_G_average",all_averages["LCZ_G_average"])

LCZ_2_A_night_test2["Datetime"]= pd.to_datetime(LCZ_2_A_night_test2["Datetime"])
LCZ_2_A_night_test2.set_index("Datetime")
# Out:
#                      LCZ_4_average  LCZ_G_average
# Datetime
# 2022-07-01 00:00:00           19.2        21.0350
# 2022-07-01 00:05:00           19.2        20.9625
# 2022-07-01 00:10:00           19.2        20.9725
# 2022-07-01 00:15:00           19.2        20.9775
# 2022-07-01 00:20:00           19.2        20.9425
# ...                            ...            ...
# 2022-09-30 03:40:00            4.0         5.6800
# 2022-09-30 03:45:00            4.0         5.6875
# 2022-09-30 03:50:00            4.0         5.7550
# 2022-09-30 03:55:00            4.0         5.7675
# 2022-09-30 04:00:00            4.0         5.6450
#
# [4508 rows x 2 columns]

# %%
LCZ_2_A_night_test2[LCZ_2_A_night_test2.Datetime.between("2022-09-01 00:00:00","2022-09-30 04:00:00")]
# Out:
#                 Datetime  LCZ_4_average  LCZ_G_average
# 3038 2022-09-01 00:00:00           14.7        14.6425
# 3039 2022-09-01 00:05:00           14.7        14.6350
# 3040 2022-09-01 00:10:00           14.7        14.6225
# 3041 2022-09-01 00:15:00           14.7        14.6175
# 3042 2022-09-01 00:20:00           14.7        14.6525
# ...                  ...            ...            ...
# 4503 2022-09-30 03:40:00            4.0         5.6800
# 4504 2022-09-30 03:45:00            4.0         5.6875
# 4505 2022-09-30 03:50:00            4.0         5.7550
# 4506 2022-09-30 03:55:00            4.0         5.7675
# 4507 2022-09-30 04:00:00            4.0         5.6450
#
# [1470 rows x 3 columns]

# %%
LCZ_2_A_night_test2.plot(x="Datetime")
# Out:
# <Axes: xlabel='Datetime'>

# %%
adf_table2 = LCZ_2_A_night_test2.drop('Datetime', axis = 1)
adf_table2.apply(adf_test, axis = 0)
# Out:
#                       LCZ_4_average  LCZ_G_average
# Test Statistic            -3.436794      -3.441309
# P-value                    0.009767       0.009629
# Lags Used                  0.000000       0.000000
# No of Observations      4507.000000    4507.000000
# Critical Value (1%)       -3.431802      -3.431802
# Critical Value (5%)       -2.862182      -2.862182
# Critical Value (10%)      -2.567111      -2.567111

# %%
ccf_ielts2 = ccf_values(LCZ_2_A_night_test2['LCZ_4_average'], LCZ_2_A_night_test2['LCZ_G_average'])
ccf_ielts2
# Out:
# array([-0.00065251, -0.00129657, -0.0019415 , ..., -0.00283799,
#        -0.00189481, -0.00095324])

# %%
lags2= signal.correlation_lags(len(LCZ_2_A_night_test2['LCZ_4_average']), len(LCZ_2_A_night_test2['LCZ_G_average']))

# %%
ccf_plot(lags2, ccf_ielts2)

# %%
####################################################################################################################

# %%
test = pd.DataFrame()
test.insert(0,"Datetime", LCZ_2_night_00_40["Datetime"])
test.insert(1,"Schillerstr", LCZ_2_night_00_40["18_Schillerstr_UTC_05min_ta_2022-07"])
test.insert(2,"Fichtenberg", LCZ_6_night_00_40["31_Fichtenberg_UTC_05min_ta_2022-07"])

# %%
test.plot(x="Datetime")
# Out:
# <Axes: xlabel='Datetime'>

# %%
adf_table3 = test.drop('Datetime', axis = 1)
adf_table3.apply(adf_test, axis = 0)
# Out:
#                       Schillerstr  Fichtenberg
# Test Statistic          -3.273697    -3.333183
# P-value                  0.016096     0.013459
# Lags Used                0.000000     0.000000
# No of Observations    4507.000000  4507.000000
# Critical Value (1%)     -3.431802    -3.431802
# Critical Value (5%)     -2.862182    -2.862182
# Critical Value (10%)    -2.567111    -2.567111

# %%
ccf_ielts3 = ccf_values(test['Schillerstr'], test['Fichtenberg'])
ccf_ielts3
# Out:
# array([-0.00079592, -0.00157761, -0.002348  , ..., -0.00225492,
#        -0.00152019, -0.00077011])

# %%
lags3= signal.correlation_lags(len(test['Schillerstr']), len(test['Fichtenberg']))

# %%
ccf_plot(lags3, ccf_ielts3)

# %%
original_x = pd.Series(np.random.uniform(size=100))
original_y = 1.3*original_x + np.random.normal(0, 0.1, size=100)
original = pd.DataFrame()
original.insert(0,'c1', original_x)
original.insert(1,'c2', original_y)
original
# Out:
#           c1        c2
# 0   0.866315  1.195667
# 1   0.101885  0.151307
# 2   0.653083  0.716272
# 3   0.726430  0.819832
# 4   0.891749  1.248893
# ..       ...       ...
# 95  0.829264  0.901916
# 96  0.680343  1.063433
# 97  0.781221  0.964652
# 98  0.631941  0.718557
# 99  0.963540  1.268844
#
# [100 rows x 2 columns]

# %%
original.apply(adf_test, axis = 0)
# Out:
#                                 c1            c2
# Test Statistic       -8.979732e+00 -9.372344e+00
# P-value               7.365580e-15  7.320158e-16
# Lags Used             0.000000e+00  0.000000e+00
# No of Observations    9.900000e+01  9.900000e+01
# Critical Value (1%)  -3.498198e+00 -3.498198e+00
# Critical Value (5%)  -2.891208e+00 -2.891208e+00
# Critical Value (10%) -2.582596e+00 -2.582596e+00

# %%
ccf_ielts4 = ccf_values(original["c1"],original["c2"])
ccf_ielts4
# Out:
# array([ 1.87887963e-02, -1.83586570e-02,  1.49194094e-02,  1.45140371e-02,
#         1.94324992e-02, -2.85711397e-03,  2.83892574e-02, -1.12581231e-02,
#         1.87585658e-03,  6.89527001e-03,  1.90733352e-02, -4.39846370e-03,
#        -2.23753249e-02,  4.39575230e-03,  5.08389208e-02,  1.95498794e-03,
#         4.52661439e-02,  3.48481523e-02,  1.23674600e-03,  1.81042150e-02,
#         5.57810240e-02, -7.14484122e-02, -7.40820069e-02,  2.00959601e-02,
#        -3.73502117e-02, -9.50470993e-02, -3.52962471e-02,  1.75958789e-02,
#        -1.69742365e-02, -7.53198792e-03,  3.58107854e-03, -1.66502778e-02,
#        -4.19814183e-02,  4.16151898e-02,  3.58919573e-02,  7.17754036e-03,
#         2.09375102e-03,  1.17556855e-01, -6.65915594e-02, -2.05169398e-02,
#         8.49029840e-02,  6.14406090e-02, -1.26230138e-01,  1.56615884e-02,
#        -8.30648484e-02, -9.39962700e-02, -3.80902760e-02, -1.07918273e-01,
# ...

# %%
lags4= signal.correlation_lags(len(original["c1"]), len(original["c2"]))

# %%
ccf_plot(lags4, ccf_ielts4)

# %%
de=test.loc[(test['Datetime'] > '2022-08-04 00:00:00') & (test['Datetime'] < '2022-08-04 04:00:00')]

# %%
full_print(de)
# Out:
#                 Datetime  Schillerstr  Fichtenberg
# 1667 2022-08-04 00:05:00        24.64         24.1
# 1668 2022-08-04 00:10:00        24.60         24.0
# 1669 2022-08-04 00:15:00        24.56         23.9
# 1670 2022-08-04 00:20:00        24.47         23.9
# 1671 2022-08-04 00:25:00        24.49         23.8
# 1672 2022-08-04 00:30:00        24.52         23.7
# 1673 2022-08-04 00:35:00        24.46         23.6
# 1674 2022-08-04 00:40:00        24.42         23.6
# 1675 2022-08-04 00:45:00        24.41         23.5
# 1676 2022-08-04 00:50:00        24.31         23.5
# 1677 2022-08-04 00:55:00        24.23         23.6
# 1678 2022-08-04 01:00:00        24.23         23.5
# 1679 2022-08-04 01:05:00        24.22         23.4
# 1680 2022-08-04 01:10:00        24.29         23.4
# 1681 2022-08-04 01:15:00        24.19         23.3
# 1682 2022-08-04 01:20:00        24.11         23.3
# 1683 2022-08-04 01:25:00        24.03         23.3
# ...

# %%
adf_table3 = test.drop('Datetime', axis = 1)
adf_table3.apply(adf_test, axis = 0)
# Out:
#                       Schillerstr  Fichtenberg
# Test Statistic          -3.273697    -3.333183
# P-value                  0.016096     0.013459
# Lags Used                0.000000     0.000000
# No of Observations    4507.000000  4507.000000
# Critical Value (1%)     -3.431802    -3.431802
# Critical Value (5%)     -2.862182    -2.862182
# Critical Value (10%)    -2.567111    -2.567111

# %%
ccf_ielts3 = ccf_values(test['Schillerstr'], test['Fichtenberg'])
ccf_ielts3
# Out:
# array([-0.00079592, -0.00157761, -0.002348  , ..., -0.00225492,
#        -0.00152019, -0.00077011])

# %%
lags3= signal.correlation_lags(len(test['Schillerstr']), len(test['Fichtenberg']))

# %%
ccf_plot(lags3, ccf_ielts3)
