# %%
import pandas as pd
import numpy as np
from database_functions import full_print
import seaborn as sns
import matplotlib.pyplot as plt
#https://doi.org/10.1016/j.uclim.2021.101012

# %%
LCZ_2_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_day_06_18.DAT",",")
LCZ_4_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_day_06_18.DAT",",")
LCZ_6_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_day_06_18.DAT",",")
LCZ_A_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_A_day_06_18.DAT",",")
LCZ_B_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_B_day_06_18.DAT",",")
LCZ_D_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_D_day_06_18.DAT",",")
LCZ_G_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_G_day_06_18.DAT",",")
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\1406109581.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_2_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_day_06_18.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\1406109581.py:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_4_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_day_06_18.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\1406109581.py:3: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_6_day_06_18 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_day_06_18.DAT",",")
# ...

# %%
LCZ_2_day_06_18["Datetime"]=pd.to_datetime(LCZ_2_day_06_18["Datetime"])
LCZ_4_day_06_18["Datetime"]=pd.to_datetime(LCZ_4_day_06_18["Datetime"])
LCZ_6_day_06_18["Datetime"]=pd.to_datetime(LCZ_6_day_06_18["Datetime"])
LCZ_A_day_06_18["Datetime"]=pd.to_datetime(LCZ_A_day_06_18["Datetime"])
LCZ_B_day_06_18["Datetime"]=pd.to_datetime(LCZ_B_day_06_18["Datetime"])
LCZ_D_day_06_18["Datetime"]=pd.to_datetime(LCZ_D_day_06_18["Datetime"])
LCZ_G_day_06_18["Datetime"]=pd.to_datetime(LCZ_G_day_06_18["Datetime"])

# %%
LCZ_6_day_06_18.drop(columns = ['12_Petitweg_UTC_05min_ta_2022-07'], inplace=True)
LCZ_6_day_06_18
# Out:
#                  Datetime  01_Amselgrund-1_UTC_05min_ta_2022-07  \
# 0     2022-07-01 06:00:00                                 23.50
# 1     2022-07-01 06:05:00                                 23.50
# 2     2022-07-01 06:10:00                                 23.29
# 3     2022-07-01 06:15:00                                 23.35
# 4     2022-07-01 06:20:00                                 23.36
# ...                   ...                                   ...
# 13335 2022-09-30 17:40:00                                 10.06
# 13336 2022-09-30 17:45:00                                  9.89
# 13337 2022-09-30 17:50:00                                  9.70
# 13338 2022-09-30 17:55:00                                  9.57
# 13339 2022-09-30 18:00:00                                  9.47
#
#        02_Amselgrund-2_UTC_05min_ta_2022-07  \
# 0                                     23.35
# 1                                     23.31
# 2                                     23.52
# ...

# %%
###############################################################################################################################################################

# %%
###################################################Afternoon####################################################################

# %%
def box_plot_specific_date(dataframe, start_date, end_date, fig_size=None, rot_x=None, x=None, y_lim=None ):
    dataframe1=dataframe.copy(deep=True)
    dataframe1=dataframe1.loc[(dataframe['Datetime'] > start_date) & (dataframe['Datetime'] < end_date)]
    dataframe1.drop(columns='Datetime',inplace=True)
    print(dataframe1.median())
    label=[]
    for x in dataframe1.columns:
        label.append(x)
        
    plt.figure(figsize=fig_size)
    t=sns.boxplot(data=dataframe1)
    if y_lim is not None:
        t.set_ylim([y_lim[0],y_lim[1]])
    
    t.set_xticklabels(labels=label, rotation=rot_x)
    #dataframe1.boxplot(figsize=fig_size, rot=rot_x)
    
    return None

# %%
box_plot_specific_date(LCZ_2_day_06_18,'2022-08-04 12:55:00','2022-08-04 16:05:00',(20,4), 45,'Datetime', (31,39))
# Out:
# 18_Schillerstr_UTC_05min_ta_2022-07    36.2300
# 19_Galvanistr_UTC_05min_ta_2022-07     37.1400
# 33_Jagow_UTC_05min_ta_2022-07          35.7000
# 34_Planetarium_UTC_05min_ta_2022-07    36.9000
# average                                36.5275
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_4_day_06_18,'2022-08-04 12:55:00','2022-08-04 16:05:00',(20,4), 45,'Datetime', (31,39))
# Out:
# 28_Marzahn_UTC_05min_ta_2022-07    36.6
# average                            36.6
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_6_day_06_18,'2022-08-04 12:55:00','2022-08-04 16:05:00',(20,4), 45,'Datetime', (31,39))
# Out:
# 01_Amselgrund-1_UTC_05min_ta_2022-07          36.130
# 02_Amselgrund-2_UTC_05min_ta_2022-07          35.400
# 08_Prignitzstr_UTC_05min_ta_2022-07           36.380
# 17_Martin-Hoffmannstr_UTC_05min_ta_2022-07    31.400
# 31_Fichtenberg_UTC_05min_ta_2022-07           37.700
# average                                       35.416
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_A_day_06_18,'2022-08-04 12:55:00','2022-08-04 16:05:00',(20,4), 45,'Datetime', (31,39))
# Out:
# 04_Preiss-1_UTC_05min_ta_2022-07       36.100
# 05_Preiss-2_UTC_05min_ta_2022-07       35.090
# 07_Wald-Tegel_UTC_05min_ta_2022-07     34.640
# 26_Tegel-Forst_UTC_05min_ta_2022-07    38.300
# average                                36.095
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_B_day_06_18,'2022-08-04 12:55:00','2022-08-04 16:05:00',(20,4), 45,'Datetime', (31,39))
# Out:
# 20_Zoo_UTC_05min_ta_2022-07                   35.690000
# 21_Waldschulallee_UTC_05min_ta_2022-07        38.380000
# 22_Botanischer-Garten_UTC_05min_ta_2022-07    37.000000
# average                                       36.916667
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_D_day_06_18,'2022-08-04 12:55:00','2022-08-04 16:05:00',(20,4), 45,'Datetime', (31,39))
# Out:
# 10_Buchholzerstr_UTC_05min_ta_2022-07    37.310000
# 11_Elisabeth-Aue_UTC_05min_ta_2022-07    36.840000
# 29_Gatow_UTC_05min_ta_2022-07            35.300000
# average                                  36.523333
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_G_day_06_18,'2022-08-04 12:55:00','2022-08-04 16:05:00',(20,4), 45,'Datetime', (31,39))
# Out:
# 06_Ruderclub_UTC_05min_ta_2022-07      34.61
# 23_Mueggelsee_UTC_05min_ta_2022-07     34.30
# 25_Tegeler-See_UTC_05min_ta_2022-07    34.30
# 27_Pichelsdorf_UTC_05min_ta_2022-07    36.30
# average                                35.03
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
#######################################################################################################################

# %%
###################################################Evening####################################################################

# %%
LCZ_2_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_day_06_21.DAT",",")
LCZ_4_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_day_06_21.DAT",",")
LCZ_6_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_day_06_21.DAT",",")
LCZ_A_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_A_day_06_21.DAT",",")
LCZ_B_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_B_day_06_21.DAT",",")
LCZ_G_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_G_day_06_21.DAT",",")
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\1333523452.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_2_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_day_06_21.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\1333523452.py:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_4_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_day_06_21.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\1333523452.py:3: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_6_day_06_21 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_day_06_21.DAT",",")
# ...

# %%
LCZ_6_day_06_21.drop(columns = ['12_Petitweg_UTC_05min_ta_2022-07'], inplace=True)
LCZ_6_day_06_21
# Out:
#                   Datetime  01_Amselgrund-1_UTC_05min_ta_2022-07  \
# 0      2022-07-01 06:00:00                                 23.50
# 1      2022-07-01 06:05:00                                 23.50
# 2      2022-07-01 06:10:00                                 23.29
# 3      2022-07-01 06:15:00                                 23.35
# 4      2022-07-01 06:20:00                                 23.36
# ...                    ...                                   ...
# 26384  2022-09-30 20:40:00                                  7.01
# 26385  2022-09-30 20:45:00                                  6.91
# 26386  2022-09-30 20:50:00                                  6.85
# 26387  2022-09-30 20:55:00                                  6.76
# 26388  2022-09-30 21:00:00                                  6.77
#
#        02_Amselgrund-2_UTC_05min_ta_2022-07  \
# 0                                     23.35
# 1                                     23.31
# 2                                     23.52
# ...

# %%
box_plot_specific_date(LCZ_2_day_06_21,'2022-08-04 16:55:00','2022-08-04 18:05:00',(20,4), 45,'Datetime', (28,37))
# Out:
# 18_Schillerstr_UTC_05min_ta_2022-07    35.2600
# 19_Galvanistr_UTC_05min_ta_2022-07     35.3500
# 33_Jagow_UTC_05min_ta_2022-07          34.5000
# 34_Planetarium_UTC_05min_ta_2022-07    36.3000
# average                                35.3525
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_4_day_06_21,'2022-08-04 16:55:00','2022-08-04 18:05:00',(20,4), 45,'Datetime', (28,37))
# Out:
# 28_Marzahn_UTC_05min_ta_2022-07    34.3
# average                            34.3
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_6_day_06_21,'2022-08-04 16:55:00','2022-08-04 18:05:00',(20,4), 45,'Datetime', (28,37))
# Out:
# 01_Amselgrund-1_UTC_05min_ta_2022-07          33.280
# 02_Amselgrund-2_UTC_05min_ta_2022-07          32.230
# 08_Prignitzstr_UTC_05min_ta_2022-07           34.280
# 17_Martin-Hoffmannstr_UTC_05min_ta_2022-07    29.580
# 31_Fichtenberg_UTC_05min_ta_2022-07           34.000
# average                                       32.666
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_A_day_06_21,'2022-08-04 16:55:00','2022-08-04 18:05:00',(20,4), 45,'Datetime', (28,37))
# Out:
# 04_Preiss-1_UTC_05min_ta_2022-07       34.58
# 05_Preiss-2_UTC_05min_ta_2022-07       33.47
# 07_Wald-Tegel_UTC_05min_ta_2022-07     31.83
# 26_Tegel-Forst_UTC_05min_ta_2022-07    33.80
# average                                33.42
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_B_day_06_21,'2022-08-04 16:55:00','2022-08-04 18:05:00',(20,4), 45,'Datetime', (28,37))
# Out:
# 20_Zoo_UTC_05min_ta_2022-07                   34.020000
# 21_Waldschulallee_UTC_05min_ta_2022-07        33.700000
# 22_Botanischer-Garten_UTC_05min_ta_2022-07    34.100000
# average                                       34.006667
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_G_day_06_21,'2022-08-04 16:55:00','2022-08-04 18:05:00',(20,4), 45,'Datetime', (28,37))
# Out:
# 06_Ruderclub_UTC_05min_ta_2022-07      33.510
# 23_Mueggelsee_UTC_05min_ta_2022-07     33.600
# 25_Tegeler-See_UTC_05min_ta_2022-07    34.900
# 27_Pichelsdorf_UTC_05min_ta_2022-07    36.700
# average                                34.795
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
###################################################Night####################################################################

# %%
LCZ_2_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_night_00_40.DAT",",")
LCZ_4_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_night_00_40.DAT",",")
LCZ_6_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_night_00_40.DAT",",")
LCZ_A_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_A_night_00_40.DAT",",")
LCZ_B_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_B_night_00_40.DAT",",")
LCZ_D_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_D_night_00_40.DAT",",")
LCZ_G_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_G_night_00_40.DAT",",")
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\2151176341.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_2_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_2_night_00_40.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\2151176341.py:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_4_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_4_night_00_40.DAT",",")
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\2151176341.py:3: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   LCZ_6_night_00_40 = pd.read_csv("C:/Users/s9dhc/WS2023/climate/LCZ_6_night_00_40.DAT",",")
# ...

# %%
LCZ_2_night_00_40["Datetime"]=pd.to_datetime(LCZ_2_night_00_40["Datetime"])
LCZ_4_night_00_40["Datetime"]=pd.to_datetime(LCZ_4_night_00_40["Datetime"])
LCZ_6_night_00_40["Datetime"]=pd.to_datetime(LCZ_6_night_00_40["Datetime"])
LCZ_A_night_00_40["Datetime"]=pd.to_datetime(LCZ_A_night_00_40["Datetime"])
LCZ_B_night_00_40["Datetime"]=pd.to_datetime(LCZ_B_night_00_40["Datetime"])
LCZ_D_night_00_40["Datetime"]=pd.to_datetime(LCZ_D_night_00_40["Datetime"])
LCZ_G_night_00_40["Datetime"]=pd.to_datetime(LCZ_G_night_00_40["Datetime"])

# %%
LCZ_6_night_00_40.drop(columns = ['12_Petitweg_UTC_05min_ta_2022-07'], inplace=True)
LCZ_6_night_00_40
# Out:
#                 Datetime  01_Amselgrund-1_UTC_05min_ta_2022-07  \
# 0    2022-07-01 00:00:00                                 19.67
# 1    2022-07-01 00:05:00                                 19.60
# 2    2022-07-01 00:10:00                                 19.58
# 3    2022-07-01 00:15:00                                 19.49
# 4    2022-07-01 00:20:00                                 19.51
# ...                  ...                                   ...
# 4503 2022-09-30 03:40:00                                  2.90
# 4504 2022-09-30 03:45:00                                  2.88
# 4505 2022-09-30 03:50:00                                  2.84
# 4506 2022-09-30 03:55:00                                  2.85
# 4507 2022-09-30 04:00:00                                  2.86
#
#       02_Amselgrund-2_UTC_05min_ta_2022-07  \
# 0                                    19.25
# 1                                    19.20
# 2                                    19.12
# ...

# %%
box_plot_specific_date(LCZ_2_night_00_40,'2022-08-04 02:55:00','2022-08-04 06:05:00',(20,4), 45,'Datetime')
# Out:
# 18_Schillerstr_UTC_05min_ta_2022-07    23.1000
# 19_Galvanistr_UTC_05min_ta_2022-07     21.9500
# 33_Jagow_UTC_05min_ta_2022-07          22.1000
# 34_Planetarium_UTC_05min_ta_2022-07    21.0000
# average                                22.0325
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_4_night_00_40,'2022-08-04 02:55:00','2022-08-04 06:05:00',(20,4), 45,'Datetime')
# Out:
# 28_Marzahn_UTC_05min_ta_2022-07    18.4
# average                            18.4
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_6_night_00_40,'2022-08-04 02:55:00','2022-08-04 06:05:00',(20,4), 45,'Datetime')
# Out:
# 01_Amselgrund-1_UTC_05min_ta_2022-07          18.410
# 02_Amselgrund-2_UTC_05min_ta_2022-07          17.760
# 08_Prignitzstr_UTC_05min_ta_2022-07           17.890
# 17_Martin-Hoffmannstr_UTC_05min_ta_2022-07    15.840
# 31_Fichtenberg_UTC_05min_ta_2022-07           21.800
# average                                       18.344
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_A_night_00_40,'2022-08-04 02:55:00','2022-08-04 06:05:00',(20,4), 45,'Datetime')
# Out:
# 04_Preiss-1_UTC_05min_ta_2022-07       17.1800
# 05_Preiss-2_UTC_05min_ta_2022-07       18.9600
# 07_Wald-Tegel_UTC_05min_ta_2022-07     18.5800
# 26_Tegel-Forst_UTC_05min_ta_2022-07    18.4000
# average                                18.2625
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_B_night_00_40,'2022-08-04 02:55:00','2022-08-04 06:05:00',(20,4), 45,'Datetime')
# Out:
# 20_Zoo_UTC_05min_ta_2022-07                   20.26
# 21_Waldschulallee_UTC_05min_ta_2022-07        17.73
# 22_Botanischer-Garten_UTC_05min_ta_2022-07    17.60
# average                                       18.50
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_D_night_00_40,'2022-08-04 02:55:00','2022-08-04 06:05:00',(20,4), 45,'Datetime')
# Out:
# 10_Buchholzerstr_UTC_05min_ta_2022-07    16.900000
# 11_Elisabeth-Aue_UTC_05min_ta_2022-07    14.910000
# 29_Gatow_UTC_05min_ta_2022-07            17.600000
# average                                  16.433333
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
box_plot_specific_date(LCZ_G_night_00_40,'2022-08-04 02:55:00','2022-08-04 06:05:00',(20,4), 45,'Datetime')
# Out:
# 06_Ruderclub_UTC_05min_ta_2022-07      18.6100
# 23_Mueggelsee_UTC_05min_ta_2022-07     20.6000
# 25_Tegeler-See_UTC_05min_ta_2022-07    20.6000
# 27_Pichelsdorf_UTC_05min_ta_2022-07    20.4000
# average                                20.0275
# dtype: float64
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\4039610960.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   t.set_xticklabels(labels=label, rotation=rot_x)

# %%
def heat_map_specific_date(dataframe, start_date, end_date, fig_size=None, rot_x=None, rot_y=None, x=None,v_min=None, v_max=None ):
    dataframe1=dataframe.copy(deep=True)
    dataframe1=dataframe1.loc[(dataframe1['Datetime'] > start_date) & (dataframe1['Datetime'] < end_date)]
    ylabels = dataframe1["Datetime"]
    dataframe1.drop(columns='Datetime',inplace=True)
    xlabel=[]
    for x in dataframe1.columns:
        xlabel.append(x)
        

        
    plt.figure(figsize=fig_size)
    t=sns.heatmap(dataframe1, square=True,cbar_kws={'fraction' : 0.01},cmap='OrRd',linewidth=1, vmin =v_min, vmax=v_max)
    t.set_xticklabels(labels=xlabel, rotation=rot_x)
    t.set_yticklabels(ylabels, rotation=rot_y)
    
    #dataframe1.boxplot(figsize=fig_size, rot=rot_x)
    
    return None

# %%
LCZ_2_day_06_18
# Out:
#                  Datetime  18_Schillerstr_UTC_05min_ta_2022-07  \
# 0     2022-07-01 06:00:00                                24.25
# 1     2022-07-01 06:05:00                                24.21
# 2     2022-07-01 06:10:00                                24.15
# 3     2022-07-01 06:15:00                                24.32
# 4     2022-07-01 06:20:00                                24.52
# ...                   ...                                  ...
# 13335 2022-09-30 17:40:00                                13.41
# 13336 2022-09-30 17:45:00                                13.30
# 13337 2022-09-30 17:50:00                                13.18
# 13338 2022-09-30 17:55:00                                13.00
# 13339 2022-09-30 18:00:00                                13.01
#
#        19_Galvanistr_UTC_05min_ta_2022-07  33_Jagow_UTC_05min_ta_2022-07  \
# 0                                   23.99                           23.7
# ...

# %%
########################################################Afternoon###############################################################

# %%
heat_map_specific_date(LCZ_2_day_06_18,'2022-08-04 13:55:00','2022-08-04 16:05:00',(10,10), 90,None,'Datetime',None,None)

# %%
heat_map_specific_date(LCZ_6_day_06_18,'2022-08-04 13:55:00','2022-08-04 16:05:00',(10,10), 90,None,'Datetime')

# %%
heat_map_specific_date(LCZ_A_day_06_18,'2022-08-04 13:55:00','2022-08-04 16:05:00',(10,10), 90,None,'Datetime')

# %%
heat_map_specific_date(LCZ_B_day_06_18,'2022-08-04 13:55:00','2022-08-04 16:05:00',(10,10), 90,None,'Datetime')

# %%
heat_map_specific_date(LCZ_D_day_06_18,'2022-08-04 13:55:00','2022-08-04 16:05:00',(10,10), 90,None,'Datetime')

# %%
heat_map_specific_date(LCZ_G_day_06_18,'2022-08-04 13:55:00','2022-08-04 16:05:00',(10,10), 90,None,'Datetime')

# %% [markdown]
# #

# %%
############################################Night###############################################################################

# %%
heat_map_specific_date(LCZ_2_night_00_40,'2022-08-04 01:55:00','2022-08-04 06:05:00',(10,10), 90,None,'Datetime')

# %%
heat_map_specific_date(LCZ_6_night_00_40,'2022-08-04 01:55:00','2022-08-04 06:05:00',(10,10), 90,0,'Datetime')

# %%
heat_map_specific_date(LCZ_A_night_00_40,'2022-08-04 01:55:00','2022-08-04 06:05:00',(10,10), 90,0,'Datetime')

# %%
heat_map_specific_date(LCZ_B_night_00_40,'2022-08-04 01:55:00','2022-08-04 06:05:00',(10,10), 90,0,'Datetime')

# %%
heat_map_specific_date(LCZ_D_night_00_40,'2022-08-04 01:55:00','2022-08-04 06:05:00',(10,10), 90,0,'Datetime')

# %%
heat_map_specific_date(LCZ_G_night_00_40,'2022-08-04 01:55:00','2022-08-04 06:05:00',(10,10), 90,0,'Datetime')

# %%
dirunal = pd.DataFrame()
dirunal.insert(loc=0,column='LCZ_2avg',value=LCZ_2_day_06_21['average'])
dirunal.insert(loc=1,column='LCZ_4avg',value=LCZ_4_day_06_21['average'])
dirunal.insert(loc=2,column='LCZ_6avg',value=LCZ_6_day_06_21['average'])
dirunal.insert(loc=3,column='LCZ_Aavg',value=LCZ_A_day_06_21['average'])
dirunal.insert(loc=4,column='LCZ_Bavg',value=LCZ_B_day_06_21['average'])
dirunal.insert(loc=5,column='LCZ_Gavg',value=LCZ_G_day_06_21['average'])
dirunal.insert(loc=0,column='Datetime',value=LCZ_2_day_06_21['Datetime'])

# %%
dirunal=dirunal.loc[(dirunal['Datetime'] > '2022-08-04 05:55:00') & (dirunal['Datetime'] < '2022-08-04 21:05:00')]

# %%
dirunal.plot(x='Datetime', rot=90)
# Out:
# <Axes: xlabel='Datetime'>

# %%
dirunal1 = pd.DataFrame()
dirunal1.insert(loc=0,column='LCZ_2avg',value=LCZ_2_night_00_40['average'])
dirunal1.insert(loc=1,column='LCZ_4avg',value=LCZ_4_night_00_40['average'])
dirunal1.insert(loc=2,column='LCZ_6avg',value=LCZ_6_night_00_40['average'])
dirunal1.insert(loc=3,column='LCZ_Aavg',value=LCZ_A_night_00_40['average'])
dirunal1.insert(loc=4,column='LCZ_Bavg',value=LCZ_B_night_00_40['average'])
dirunal1.insert(loc=5,column='LCZ_Gavg',value=LCZ_G_night_00_40['average'])
dirunal1.insert(loc=0,column='Datetime',value=LCZ_2_night_00_40['Datetime'])

# %%
dirunal1=dirunal1.loc[(dirunal1['Datetime'] > '2022-08-04 01:55:00') & (dirunal1['Datetime'] < '2022-08-04 6:05:00')]

# %%
dirunal1.plot(x='Datetime', rot=90)
# Out:
# <Axes: xlabel='Datetime'>

# %%
LCZ_A_night_00_40.groupby(LCZ_A_night_00_40["Datetime"].dt.hour)['04_Preiss-1_UTC_05min_ta_2022-07','05_Preiss-2_UTC_05min_ta_2022-07','07_Wald-Tegel_UTC_05min_ta_2022-07','26_Tegel-Forst_UTC_05min_ta_2022-07'].mean()
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\3977630780.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_A_night_00_40.groupby(LCZ_A_night_00_40["Datetime"].dt.hour)['04_Preiss-1_UTC_05min_ta_2022-07','05_Preiss-2_UTC_05min_ta_2022-07','07_Wald-Tegel_UTC_05min_ta_2022-07','26_Tegel-Forst_UTC_05min_ta_2022-07'].mean()
#           04_Preiss-1_UTC_05min_ta_2022-07  05_Preiss-2_UTC_05min_ta_2022-07  \
# Datetime
# 0                                13.600435                         14.205054
# 1                                13.118134                         13.700861
# 2                                12.750254                         13.310254
# 3                                12.483877                         13.018107
# 4                                12.451848                         12.954891
#
#           07_Wald-Tegel_UTC_05min_ta_2022-07  \
# Datetime
# ...

# %%
LCZ_2_night_00_40.groupby(LCZ_2_night_00_40["Datetime"].dt.month_name())["18_Schillerstr_UTC_05min_ta_2022-07","19_Galvanistr_UTC_05min_ta_2022-07","33_Jagow_UTC_05min_ta_2022-07","34_Planetarium_UTC_05min_ta_2022-07"].mean()
# Out:
# C:\Users\s9dhc\AppData\Local\Temp\ipykernel_12816\654320029.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   LCZ_2_night_00_40.groupby(LCZ_2_night_00_40["Datetime"].dt.month_name())["18_Schillerstr_UTC_05min_ta_2022-07","19_Galvanistr_UTC_05min_ta_2022-07","33_Jagow_UTC_05min_ta_2022-07","34_Planetarium_UTC_05min_ta_2022-07"].mean()
#            18_Schillerstr_UTC_05min_ta_2022-07  \
# Datetime
# August                               19.525194
# July                                 17.474042
# September                            12.548150
#
#            19_Galvanistr_UTC_05min_ta_2022-07  33_Jagow_UTC_05min_ta_2022-07  \
# Datetime
# August                              18.909440                      18.975049
# July                                17.130724                      17.091639
# September                           12.176075                      12.192313
#
# ...

# %%
LCZ_B_night_00_40
# Out:
#                 Datetime  20_Zoo_UTC_05min_ta_2022-07  \
# 0    2022-07-01 00:00:00                        22.14
# 1    2022-07-01 00:05:00                        22.21
# 2    2022-07-01 00:10:00                        22.19
# 3    2022-07-01 00:15:00                        22.10
# 4    2022-07-01 00:20:00                        22.08
# ...                  ...                          ...
# 4503 2022-09-30 03:40:00                         5.61
# 4504 2022-09-30 03:45:00                         5.55
# 4505 2022-09-30 03:50:00                         5.50
# 4506 2022-09-30 03:55:00                         5.52
# 4507 2022-09-30 04:00:00                         5.38
#
#       21_Waldschulallee_UTC_05min_ta_2022-07  \
# 0                                      21.04
# 1                                      20.97
# 2                                      20.89
# 3                                      20.81
# 4                                      20.82
# ...
